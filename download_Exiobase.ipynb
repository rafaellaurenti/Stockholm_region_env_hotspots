# %%
import pandas as pd
import pymrio

# %% [markdown]
# ## EXIOBASE 3 download

# %%
# download EXIOBASE 3 if not already done (this will download the zip file and extract it to the specified folder).
exio3_folder = ("C:/EXIOBASE3/")
exio_downloadlog = pymrio.download_exiobase3(
    storage_folder=exio3_folder,
    system="pxp",
    years=[2023],
    doi="10.5281/zenodo.18937492" # Version 3.10.1, published Mar 23, 2026
)

print(exio_downloadlog)
# Out:
# Description: Download log of EXIOBASE3
# MRIO Name: EXIO3
# System: pxp
# Version: 10.5281/zenodo.18937492
# File: C:\EXIOBASE3\download_log.json
# History:
# 20260416 18:20:59 - FILEIO -  Skip download existing file IOT_2023_pxp.zip
# 20260416 18:20:59 - FILEIO -  Skip download existing file IOT_2023_pxp.zip
# 20260416 18:20:59 - FILEIO -  Skip download existing file IOT_2023_pxp.zip
# 20260416 18:20:59 - FILEIO -  Downloaded https://zenodo.org/records/18937492/files/IOT_2023_pxp.zip to IOT_2023_pxp.zip
# 20260416 18:19:39 - NOTE -  Download log created
# 20260416 18:19:39 - NOTE -  python_version: 3.14.0
# 20260416 18:19:39 - NOTE -  pymrio_version: 0.6.3
# 20260416 18:19:39 - NOTE -  os: Windows
# 20260416 18:19:39 - NOTE -  hostname: RISEPC-WvKMUDXA
# 20260416 18:19:39 - NOTE -  username: rafaella
#  ... (more lines in history)
