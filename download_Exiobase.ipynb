# %%
import pandas as pd
import pymrio

# %% [markdown]
# ## EXIOBASE 3 download

# %%
# download EXIOBASE 3 if not already done (this will download the zip file and extract it to the specified folder).
exio3_folder = ("C:/EXIOBASE3/")
exio_downloadlog = pymrio.download_exiobase3(
    storage_folder=exio3_folder,
    system="pxp",
    years=[2022],
    doi="https://doi.org/10.5281/zenodo.4588235" # V 3.8.1
)

print(exio_downloadlog)
# Out:
# Description: EXIOBASE3 metadata file for pymrio
# MRIO Name: EXIO3
# System: pxp
# Version: https://doi.org/10.5281/zenodo.4588235
# File: C:\EXIOBASE3\metadata.json
# History:
# 20260429 18:10:02 - FILEIO -  Could not find EXIOBASE 3 source file with >2022< and >pxp<
# 20260429 18:10:02 - METADATA_CHANGE -  Changed parameter "version" from "10.5281/zenodo.4588235" to "https://doi.org/10.5281/zenodo.4588235"
# 20260429 18:05:57 - FILEIO -  Could not find EXIOBASE 3 source file with >2022< and >pxp<
